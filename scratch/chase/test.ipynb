# %%
import cv2
import numpy as np
import os

# %%
path_to_frame = "/Users/alwaysanothersecret/Desktop/mario-kart-world-reader.nosync/training_data/frames/mkw_rainbow_road_p1_standard_loop_local_nochat_2026-05-11_15-48-39/000420_mkw_rainbow_road_p1_standard_loop_local_nochat_2026-05-11_15-48-39.png"
image = cv2.imread(path_to_frame)
cv2.imshow("frame 1123", image)
cv2.waitKey(0)
print(image.shape)
# cv2.destroyAllWindows()
crop_to_placement = image[430:520,805:925,:]
cv2.imshow("cropped frame 1123", crop_to_placement)
cv2.waitKey(0)
# Out:
# (540, 960, 3)
# -1
